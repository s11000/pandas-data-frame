# %% [markdown]
# <a href="https://colab.research.google.com/github/s11000/pandas-data-frame/blob/main/yolov8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.4/779.4 kB 8.5 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
yolo detect train data=coco128.yaml model=yolov8n.pt epochs=100 imgsz=640
# Out:
#   File "<ipython-input-2-882d55ae49c1>", line 1
#     yolo detect train data=coco128.yaml model=yolov8n.pt epochs=100 imgsz=640
#          ^
# SyntaxError: invalid syntax

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolov8n.pt")  # load an official model


# Predict with the model
results = model.predict(source="https://ultralytics.com/images/bus.jpg",save=True)  # predict on an image
# Out:
# ...
# 100%|██████████| 476k/476k [00:00<00:00, 49.9MB/s]
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 368.8ms
# Speed: 29.8ms preprocess, 368.8ms inference, 1661.6ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict

# %%
ls
# Out:
# sample_data/  yolov8n.pt

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolov8n.pt")  # load an official model
# Change the path to the correct path to the custom model file
model = YOLO("/content/yolov8n.pt")  # load a custom model

# Predict with the model
results = model.predict(source="https://ultralytics.com/images/bus.jpg",save=True)  # predict on an image
# Out:
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 211.8ms
# Speed: 4.8ms preprocess, 211.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict2

# %% [markdown]
# ![bus.jpg](data:image/jpeg;base64,...)
