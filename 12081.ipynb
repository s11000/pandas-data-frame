# %% [markdown]
# <a href="https://colab.research.google.com/github/s11000/pandas-data-frame/blob/main/12081.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import seaborn as sns
sns.set()
x=np.random.randn(100)
sns.distplot(x,color="g")
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from scipy.stats import *
sns.distplot(x,hist=False,fit=norm)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
import numpy as np
import matplotlib.pyplot as plt
points = np.random.uniform(-0.6,6.0,50000)
plt.hist(points,30)
plt.show()

# %%
from scipy.stats import norm
import matplotlib.pyplot as plt
x=np.arange(-6,6,0.01)
plt.plot(x,norm.pdf(x))

# %%
from scipy.stats import norm
import matplotlib.pyplot as plt
avg =10.0
stddev=1.0
points=np.random.normal(avg,stddev,10000)
plt.hist(points,58)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
s= pd.DataFrame(np.random.randn(1000)+10,columns=['value'])
fig=plt.figure(figsize=(10,6))
ax1=fig.add_subplot(2,1,1)
ax1.scatter(s.index,s.values)
plt.grid()

ax2=fig.add_subplot(2,1,2)
s.hist(bins=30,alpha=0.5,ax=ax2)
s.plot(kind='kde',secondary_y=True,ax=ax2)
plt.grid()

# %%
from scipy import stats
u=s['value'].mean()
std=s['value'].std()
stats.kstest(s['value'],'norm',(u,std))
# Out:
# KstestResult(statistic=0.02537627085908567, pvalue=0.5317027777591006)
