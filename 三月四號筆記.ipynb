# %% [markdown]
# <a href="https://colab.research.google.com/github/s11000/pandas-data-frame/blob/main/%E4%B8%89%E6%9C%88%E5%9B%9B%E8%99%9F%E7%AD%86%E8%A8%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 資料科學(Data Science)_常用套件
# 資料科學 Data Science
#
# numpy
# pandas
# scipy
# statsmodels(統計分析)
# 科學計算 scientific calculation
#
# sympy
# scipy
# 電腦視覺
#
# opencv
# 資料視覺化 Data Visulization
#
# matplotlib
# seaborn
# plotly
# .....
# 機器學習
#
# scikit-learn (sklearn)
# 機器學習與人工智慧
#
# Tensorflow
# Pytorch (torch)

# %% [markdown]
# # 作業 1: 確認開發環境的套件版本

# %%
! pip list
# Out:
# Package                       Version
# ----------------------------- ---------------------
# absl-py                       1.0.0
# alabaster                     0.7.12
# albumentations                0.1.12
# altair                        4.2.0
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arviz                         0.12.0
# astor                         0.8.1
# astropy                       4.3.1
# astunparse                    1.6.3
# atari-py                      0.2.9
# atomicwrites                  1.4.0
# attrs                         21.4.0
# audioread                     2.1.9
# autograd                      1.4
# Babel                         2.9.1
# backcall                      0.2.0
# beautifulsoup4                4.6.3
# bleach                        5.0.0
# blis                          0.4.1
# bokeh                         2.3.3
# Bottleneck                    1.3.4
# ...

# %% [markdown]
# Anaconda介紹及安裝教學
# 針對Anaconda介紹、安裝及測試做整體性的說明
# 2021全新內容歡迎參考文章 Anaconda 3 安裝教學及說明
# 除了上一篇有關Python安裝教學外，資料科學領域當中另一個重要的開發環境就屬Anaconda，本篇文章將針對Anaconda介紹、安裝及環境介紹做一個整體性的說明。
# Anaconda是目前最受歡迎的Python數據科學(Data Science)平台，除了有眾多使用者及企業用戶外，目前也超過1000種的Data Science Packages可使用(包括250多種流行的packages)，適用於Windows、Linux和MacOS 不同作業系統環境下的conda軟件包(package)和虛擬環境管理器，對於在安裝、執行及升級複雜的數據科學(Data Science)及機器學習(Machine Learning)環境上變得簡單快速，下圖是Anaconda Enterprise 5一個Overview的架構。
# https://medium.com/python4u/anaconda%E4%BB%8B%E7%B4%B9%E5%8F%8A%E5%AE%89%E8%A3%9D%E6%95%99%E5%AD%B8-f7dae6454ab6

# %% [markdown]
# # 作業 2:如何載入套件

# %%
import pandas as pd
import numpy as np
import tensorflow as tf

# %% [markdown]
# # 作業 3:如何學習或是使用套件

# %%
import numpy as np

b = np.linspace(0, 2, 4)
b
# Out:
# array([0.        , 0.66666667, 1.33333333, 2.        ])

# %%
c = np.linspace(0, 2, 4, endpoint=False) 
c
# Out:
# array([0. , 0.5, 1. , 1.5])

# %% [markdown]
# # 學習函式(function) linspace()的使用

# %% [markdown]
# # 官方說明 numpy.linspace

# %% [markdown]
# https://numpy.org/doc/stable/reference/generated/numpy.linspace.html
#  ![03.PNG](data:image/png;base64,...)

# %% [markdown]
# # Python numpy linspace用法及代碼示例

# %% [markdown]
# ![02.PNG](data:image/png;base64,...)

# %% [markdown]
# # Python numpy linspace用法及代碼示例

# %%
import numpy as np

numpy.linspace(
0, 
20, 
num=50, 
endpoint=True, 
retstep=False, 
dtype=None, 
axis=0)
# Out:
# array([ 0.        ,  0.40816327,  0.81632653,  1.2244898 ,  1.63265306,
#         2.04081633,  2.44897959,  2.85714286,  3.26530612,  3.67346939,
#         4.08163265,  4.48979592,  4.89795918,  5.30612245,  5.71428571,
#         6.12244898,  6.53061224,  6.93877551,  7.34693878,  7.75510204,
#         8.16326531,  8.57142857,  8.97959184,  9.3877551 ,  9.79591837,
#        10.20408163, 10.6122449 , 11.02040816, 11.42857143, 11.83673469,
#        12.24489796, 12.65306122, 13.06122449, 13.46938776, 13.87755102,
#        14.28571429, 14.69387755, 15.10204082, 15.51020408, 15.91836735,
#        16.32653061, 16.73469388, 17.14285714, 17.55102041, 17.95918367,
#        18.36734694, 18.7755102 , 19.18367347, 19.59183673, 20.        ])

# %% [markdown]
# # 學習重點:
# 函式(function)參數有哪些個?
# 那些參數有預設值?
# 那些參數一定要填
# 函式(function)回傳的資料
# 回傳的資料型態
# 可以有幾種接收值
# 範例: numpy.linspace()
# 函式(function)參數有哪些個?
# 共有多少個參數? 7 個 ==> start, stop, num,endpoint, retstep, dtype, axis
# 那些參數有預設值?
# num=50, 預設值=>50
# endpoint=True, 預設值=>True
# retstep=False, 預設值=>False
# dtype=None, 預設值=>None
# axis=0 預設值=>0
# 那些參數一定要填
# start, stop,
# 函式(function)回傳的資料
# 回傳的資料型態 ==> ndarray
# ## 可以有幾種接收值 ===> nd **粗體文字**array **粗體文字** **粗體文字**

# %% [markdown]
# ![04.PNG](data:image/png;base64,...)

# %% [markdown]
# # Python 資料分析必備套件

# %% [markdown]
# Pandas 1.x Cookbook
# Python 資料分析必備套件 Matt Harrison、Theodore Petrou 著 蔣佑仁、李侑穎 譯；施威銘研究室 監修 旗標科技
# https://github.com/PacktPublishing/Pandas-Cookbook-Second-Edition

# %% [markdown]
# ![05.PNG](data:image/png;base64,...)

# %% [markdown]
# # numpy 學習主題
# 1.資料型態 ==> N-Dimensional Arrays(ndarray)
# ndarray的屬性: 軸(axis)|維度(dimension):ndim|秩rank |形狀(shape):shape|dtype(資料型態:data type)
#
# 2.基本運算1: 建立各式各樣的ndarray
# 基本運算2: ndarray的基本運算:切片 (Slicing) ,.....
# 基本運算3: ndarray的基本數學運算
# 基本運算4: ndarray的(線性代數)數學運算
#
# 3.特殊運算 ==> 陣列擴張|廣播 (Broadcasting)
# 資料型態 ==> N-Dimensional Arrays(ndarray)
# ndarray的屬性:
# 軸(axis)|維度(dimension):ndim|秩rank |形狀(shape):shape|dtype(資料型態:data type)| 大小(元素個數):size
# ndarray的屬性:軸(axis)
# numpy axis概念整理筆記
# ndarray的屬性:維度(dimension):ndim
# import numpy as np
#
# ar2=np.array([[0,3,5],[2,8,7]]) # 產生一個 2D array
# ar2.ndim

# %%
import numpy as np

ar2=np.array([[0,3,5],[2,8,7]]) # 產生一個 2D array
ar2.ndim
# Out:
# 2

# %% [markdown]
# # ndarray的屬性:秩rank
# ndarray的屬性:形狀(shape):shape

# %%
import numpy as np

ar2=np.array([[0,3,5],[2,8,7]]) # 產生一個 2D array
ar2.shape
# Out:
# (2, 3)

# %% [markdown]
# # ndarray的屬性:大小(元素個數):size
# import numpy as np
#
# ar2=np.array([[0,3,5],[2,8,7]]) # 產生一個 2D array
# ar2.size

# %%
import numpy as np

ar2=np.array([[0,3,5],[2,8,7]]) # 產生一個 2D array
ar2.size
# Out:
# 6

# %% [markdown]
# # ndarray的屬性:dtype(資料型態:data type)
# import numpy as np
#
# ar1=np.array([2,4,6,8]);
# ar1.dtype
# ar2=np.array([2,-1,6,3], dtype='float’ );
# ar2
# ar2.dtype
# import numpy as np
#
# ar3=np.array([2.,4,6,8]);
#
# ar3.dtype

# %%
import numpy as np

ar1=np.array([2,4,6,8]); 
ar1.dtype
# Out:
# dtype('int64')

# %%
ar2=np.array([2,-1,6,3], dtype='float’ ); 
ar2
ar2.dtype
# Out:
#   File "<ipython-input-99-71b3ad84d73a>", line 1
#     ar2=np.array([2,-1,6,3], dtype='float’ );
#                                               ^
# SyntaxError: EOL while scanning string literal

# %%
import numpy as np

ar3=np.array([2.,4,6,8]); 

ar3.dtype
# Out:
# dtype('float64')

# %% [markdown]
# # ndarray的運算:型態轉換|astype()函式

# %%
f_ar = np.array([13,-3,8.88])
f_ar
intf_ar=f_ar.astype(int)
intf_ar
# Out:
# array([13, -3,  8])

# %% [markdown]
# ![06.PNG](data:image/png;base64,...)

# %%
import numpy as np
np.random.seed(0)

# %%
x1 = np.random.randint(10, size=6) 
x2 = np.random.randint(10, size=(3, 4)) 
x3 = np.random.randint(10, size=(3, 4, 5))

# %%
np.array(object, 
         dtype = None,
         copy = True, 
         order = None, 
         subok = False, 
         ndmin = 0)
# Out:
# array(<class 'object'>, dtype=object)

# %%
import numpy as np

# %%
np.array(object, 
         dtype = None,
         copy = True, 
         order = None, 
         subok = False, 
         ndmin = 0)
# Out:
# array(<class 'object'>, dtype=object)

# %%
import numpy as np
np.linspace(2.0, 3.0, num=5)
# Out:
# array([2.  , 2.25, 2.5 , 2.75, 3.  ])

# %%
np.linspace(2.0, 3.0, num=5, endpoint=False)
# Out:
# array([2. , 2.2, 2.4, 2.6, 2.8])

# %%
np.linspace(2.0, 3.0, num=5, retstep=True)
# Out:
# (array([2.  , 2.25, 2.5 , 2.75, 3.  ]), 0.25)

# %%
import matplotlib.pyplot as plt
N = 8
y = np.zeros(N)
x1 = np.linspace(0, 10, N, endpoint=True)
x2 = np.linspace(0, 10, N, endpoint=False)
plt.plot(x1, y, 'o')
 
plt.plot(x2, y + 0.5, 'o')
 
plt.ylim([-0.5, 1])
(-0.5, 1)
plt.show()

# %%
import numpy as np

# %%
np.array(object, 
         dtype = None,
         copy = True, 
         order = None, 
         subok = False, 
         ndmin = 0)
# Out:
# array(<class 'object'>, dtype=object)

# %%
import numpy as np

numpy.linspace(
0, 
20, 
num=50, 
endpoint=True, 
retstep=False, 
dtype=None, 
axis=0)
# Out:
# array([ 0.        ,  0.40816327,  0.81632653,  1.2244898 ,  1.63265306,
#         2.04081633,  2.44897959,  2.85714286,  3.26530612,  3.67346939,
#         4.08163265,  4.48979592,  4.89795918,  5.30612245,  5.71428571,
#         6.12244898,  6.53061224,  6.93877551,  7.34693878,  7.75510204,
#         8.16326531,  8.57142857,  8.97959184,  9.3877551 ,  9.79591837,
#        10.20408163, 10.6122449 , 11.02040816, 11.42857143, 11.83673469,
#        12.24489796, 12.65306122, 13.06122449, 13.46938776, 13.87755102,
#        14.28571429, 14.69387755, 15.10204082, 15.51020408, 15.91836735,
#        16.32653061, 16.73469388, 17.14285714, 17.55102041, 17.95918367,
#        18.36734694, 18.7755102 , 19.18367347, 19.59183673, 20.        ])

# %%
import numpy as np

ar2=np.array([[0,3,5],[2,8,7]]) # 產生一個 2D array
ar2.ndim
# Out:
# 2

# %%
import numpy as np

ar2=np.array([[0,3,5],[2,8,7]]) # 產生一個 2D array
ar2.shape
# Out:
# (2, 3)

# %%
import numpy as np

ar2=np.array([[0,3,5],[2,8,7]]) # 產生一個 2D array
ar2.size
# Out:
# 6

# %%
import numpy as np

ar1=np.array([2,4,6,8]); 
ar1.dtype
# Out:
# dtype('int64')

# %%
ar2=np.array([2,-1,6,3], dtype='float’ ); 
ar2
ar2.dtype
# Out:
#   File "<ipython-input-88-71b3ad84d73a>", line 1
#     ar2=np.array([2,-1,6,3], dtype='float’ );
#                                               ^
# SyntaxError: EOL while scanning string literal

# %%
import numpy as np

ar3=np.array([2.,4,6,8]); 

ar3.dtype
# Out:
# dtype('float64')

# %%
f_ar = np.array([13,-3,8.88])
f_ar
# Out:
# array([13.  , -3.  ,  8.88])

# %%
import numpy as np

#define numpy array
x = np.random.normal(loc=0, scale=1, size=20)

#print values in arrary
print(x)
# Out:
# [-0.10621865  0.64271628  0.62400653  0.44057128  0.32548174  0.66316845
#   0.09573808 -1.70150033 -0.58655025 -0.42372221  0.59820544 -0.52889226
#  -0.80440427 -2.62589671  0.39795909  0.82380932 -0.73931699 -0.98800683
#  -0.18673121 -0.48140124]
